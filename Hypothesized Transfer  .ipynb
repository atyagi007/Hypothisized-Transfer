# %%
# %matplotlib notebook
import math
import matplotlib.pyplot as plt
import pandas as pd
from itertools import count
from IPython import display
import numpy as np 
from matplotlib.animation import FuncAnimation
fig = plt.figure()

massEarth = 5.972 * (10**24)
massSat = 4989516.07 #420000
g = 6.67 * (10**-11)
# Earth's Position
ep_x = 0
ep_y = 0
x_coordinates = [ep_x]
y_coordinates = [ep_y]

totalTime = 25
plt.scatter(x_coordinates, y_coordinates)
#plt.show()

rad = 420000 + (6.371 * (10**6))
# dt 
dt = 20

# rocket position and velocity initially 
np_x = rad
np_y = 0

nv_x = 0
nv_y = 7700
vel = 0
# total acc
acc = 0 
marsAcc = 0 
#components of acceleration
acc_x = 0 
acc_y = 0 

m_x = 0

theta = 0

#just some vars i am using to make this run only 5 times at for now
thing = 1 
counter = 0 

xList = [np_x]
yList =[np_y]

maxPeriod = 100000000000000000 
#loop
ctrl = 0
ctrl2 = 0
ctrl3 = 0
ctrl4 = 0
ctrl5 = 0
ctrl6 = 0
ctrl7 = 0
ctrl8 = 0 
ctrl9 = 0 
ctrl10 = 0
ctrl11 = 0
ctrl12 = 0



#fuel variables

chngVel = 0
exhaustVel = 3000
massBefore = 944546.7677
fuelList = [0]
timeList = [0]
def rocketEquation (chng, exhaust, massBefore):
    massAfter = massBefore/(math.e**(chng/exhaust))
   # print(massBefore - massAfter)
    return massBefore - massAfter 
while thing == 1:
    #print("Counter:  ",counter)
    #finding next position
    period = math.sqrt((4.0 * ((math.pi)**2)*(rad**3))/(g*massEarth))
   # print(period)
    if ( period < 5700 and ctrl < 1 and 2300 > counter > 2000) :
        #vel = math.sqrt((nv_y**2) + (nv_x**2))
        
        #nv_y += 582
        vel = math.sqrt((nv_x**2)+(nv_y**2))
        vel += 500
        print("hi")
        fuelUsed = rocketEquation(500,exhaustVel,massBefore)
        massBefore = massBefore - fuelUsed
        print(massBefore)
        fuelList.append(fuelUsed)
        timeList.append(counter*dt)
      
        nv_y = math.sqrt((vel**2) - (nv_x**2))
       # nv_x = math.sqrt((vel**2) - (nv_y**2))

        ctrl += 1 
    elif ( period < 5700 and ctrl2 < 1 and 2600 > counter > 2300) :
        #vel = math.sqrt((nv_y**2) + (nv_x**2))
        
        #nv_y += 582
        vel = math.sqrt((nv_x**2)+(nv_y**2))
        vel += 500
        fuelUsed = rocketEquation(500,exhaustVel,massBefore)
        massBefore = massBefore - fuelUsed
        print(massBefore)
        print("hi 1")
        fuelList.append(fuelUsed)
        timeList.append(counter*dt)
        nv_y = math.sqrt((vel**2) - (nv_x**2))
       # nv_x = math.sqrt((vel**2) - (nv_y**2))
        print(period)
        ctrl2 += 1    
    elif ( period < 5700 and 2900 > counter > 2600 and ctrl3 < 1 ) :##########################
        #vel = math.sqrt((nv_y**2) + (nv_x**2))
        
        #nv_y += 582
        vel = math.sqrt((nv_x**2)+(nv_y**2))
        vel += 500
        fuelUsed = rocketEquation(500,exhaustVel,massBefore)
        massBefore = massBefore - fuelUsed
        print(massBefore)
        print("hi 2")
        fuelList.append(fuelUsed)
        timeList.append(counter*dt)
        nv_y = math.sqrt((vel**2) - (nv_x**2))
       # nv_x = math.sqrt((vel**2) - (nv_y**2))

        ctrl3 += 1 
    elif ( period < 5700 and ctrl4 < 1 and 5500 > counter > 5000) :
        #vel = math.sqrt((nv_y**2) + (nv_x**2))
        
        #nv_y += 582
        vel = math.sqrt((nv_x**2)+(nv_y**2))
        vel += 500
        print("hi 3")
        fuelUsed = rocketEquation(500,exhaustVel,massBefore)
        massBefore = massBefore - fuelUsed
        fuelList.append(fuelUsed)
        timeList.append(counter*dt)
        nv_y = math.sqrt((vel**2) - (nv_x**2))
       # nv_x = math.sqrt((vel**2) - (nv_y**2))

        ctrl4 += 1 
    elif ( period < 5700 and ctrl5 < 1 and 15500 > counter >  10000) :
        #vel = math.sqrt((nv_y**2) + (nv_x**2))
        
        #nv_y += 582 688. <-----------
        vel = math.sqrt((nv_x**2)+(nv_y**2))
        vel += 500
        fuelUsed = rocketEquation(500,exhaustVel,massBefore)
        massBefore = massBefore - fuelUsed
        print("hi 4")
        fuelList.append(fuelUsed)
        timeList.append(counter*dt)
        nv_y = math.sqrt((vel**2) - (nv_x**2))
       # nv_x = math.sqrt((vel**2) - (nv_y**2))

        ctrl5 += 1 
    elif ( period < 5700 and ctrl6 < 1 and 100000 > counter >  50000) :
        #vel = math.sqrt((nv_y**2) + (nv_x**2))
        
        #nv_y += 582
        print(nv_y)
        vel = math.sqrt((nv_x**2)+(nv_y**2))
        vel += 500
        fuelUsed = rocketEquation(500,exhaustVel,massBefore)
        massBefore = massBefore - fuelUsed
        print("hi 5")
        fuelList.append(fuelUsed)
        timeList.append(counter*dt)
        nv_y = math.sqrt((vel**2) - (nv_x**2))
        print(nv_y)
       # nv_x = math.sqrt((vel**2) - (nv_y**2))

        ctrl6 += 1 
    else: 
    
        timeList.append(counter*dt)
        fuelList.append(0)
        
    np_x = np_x + (dt*nv_x )
   
    np_y = np_y + (dt*nv_y )
   # print("np_y:  ",np_y)
    # finding the acceleteration in components
    if np_y == 0 : 
        acc = np_x
    if np_y != 0:
        rad = math.sqrt(((np_x - ep_x)**2) + ((np_y - ep_y)**2))
       # print("rad:  ",rad)
        acc = -(g * massEarth)/((rad)**2)
       # print("acc:  ",acc)
        theta = math.atan2(np_x,np_y)
        #print("Theta:  ",theta)

    # Dividing into components 
    acc_x = math.sin(theta) * acc
    acc_y = math.cos(theta) * acc 
    
    
    # finding next Velocity 
    nv_x = nv_x + (dt * acc_x)
    nv_y = nv_y + (dt * acc_y)

    #print(np_y)
    x1_coordinates = [ep_x,np_x]
    y1_coordinates = [ep_y,np_y]

    #plt.scatter(x1_coordinates, y1_coordinates)
    #anim = animation.FuncAnimation(fig, animate, init_func=init, frames=100, interval=20, blit=True)
    #plt.show()
    
    #Putting new position values into a list 
   # print(vel)
   # print(maxPeriod)
    
    #vel = math.sqrt((nv_x**2)+(nv_y**2))
    xList.append(np_x)
    yList.append(np_y)
    if counter > (25 * 24 * 60 * 60)/dt :
        thing = 0
       
    counter += 1
    #print(counter)


ep_x = 0
ep_y = 0     
x_coordinates = [ep_x]     
y_coordinates = [ep_y]       
plt.scatter(x_coordinates, y_coordinates)  
plt.xlabel("Distance in X direction (Meters)")
plt.ylabel("Distance in Y direction (Meters)")
#x_m = [mp_x]
#y_m = [mp_y]
#plt.scatter(x_m,y_m)
limSize = 223e6 #44.6e6
plt.xlim([-limSize,limSize])                         
plt.ylim([-limSize,limSize])
maxFromEarth = (limSize/2) * 0.000621371
plot1 = plt.figure(1)
plt.plot(xList,yList)
plt.show()
print("total time for leaving Earth's Orbit: ", totalTime, "days")
print("Max distance from the earth in orbit: ", maxFromEarth, "miles" )
plot2 = plt.figure(2)
plt.xlim([0,300000])

plt.plot(timeList,np.cumsum(fuelList))
plt.xlabel("Time in Intervals of 20 seconds")
plt.ylabel("Fuel used over time")
plt.show()

#fig = plt.figure()
#def animate(i):
   # xl.append(xList[next(index)])
   # y1.append(yList[next(index)])
   # xo = xList
  #  yo = yList
   # plt.cla()
 #   plt.scatter(x_coordinates, y_coordinates)
    #plt.plot(xo,yo)
   # plt.tight_layout()

#ani = FuncAnimation(fig, animate,frames = 100, interval= 20)
#video = ani.to_html5_video()
#html = display.HTML(video)
#display.display(html)
#plt.close()

#plt.tight_layout()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# hi
# 799541.5771625502
# 676797.3333583176
# hi 1
# 5698.82354906506
# 572896.5741425167
# hi 2
# hi 3
# hi 4
# 9761.86539323286
# hi 5
# 10278.80518212807
# total time for leaving Earth's Orbit:  25 days
# Max distance from the earth in orbit:  69282.8665 miles
# <img src="data:image/png;base64,..." width="640">
